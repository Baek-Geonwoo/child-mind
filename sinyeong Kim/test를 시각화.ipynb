# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import polars as pl
test_series = pl.scan_parquet('/content/drive/MyDrive/ai경진대회/Child Mind/test_series.parquet')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# %%
tmp = test_series.collect()

# %%
print(test_series.select("series_id").collect())
# Out:
# shape: (450, 1)
# ┌──────────────┐
# │ series_id    │
# │ ---          │
# │ str          │
# ╞══════════════╡
# │ 038441c925bb │
# │ 038441c925bb │
# │ 038441c925bb │
# │ 038441c925bb │
# │ …            │
# │ 0402a003dae9 │
# │ 0402a003dae9 │
# │ 0402a003dae9 │
# │ 0402a003dae9 │
# └──────────────┘

# %%
tmp1 = tmp.filter(pl.col("series_id") == "038441c925bb")

# %%
print(tmp1[0], tmp1[-1])
# Out:
# shape: (1, 5)
# ┌──────────────┬──────┬──────────────────────────┬────────┬────────┐
# │ series_id    ┆ step ┆ timestamp                ┆ anglez ┆ enmo   │
# │ ---          ┆ ---  ┆ ---                      ┆ ---    ┆ ---    │
# │ str          ┆ u32  ┆ str                      ┆ f32    ┆ f32    │
# ╞══════════════╪══════╪══════════════════════════╪════════╪════════╡
# │ 038441c925bb ┆ 0    ┆ 2018-08-14T15:30:00-0400 ┆ 2.6367 ┆ 0.0217 │
# └──────────────┴──────┴──────────────────────────┴────────┴────────┘ shape: (1, 5)
# ┌──────────────┬──────┬──────────────────────────┬────────────┬────────┐
# │ series_id    ┆ step ┆ timestamp                ┆ anglez     ┆ enmo   │
# │ ---          ┆ ---  ┆ ---                      ┆ ---        ┆ ---    │
# │ str          ┆ u32  ┆ str                      ┆ f32        ┆ f32    │
# ╞══════════════╪══════╪══════════════════════════╪════════════╪════════╡
# │ 038441c925bb ┆ 149  ┆ 2018-08-14T15:42:25-0400 ┆ -80.153503 ┆ 0.0136 │
# ...

# %%
# vizualize these series
display(Markdown('###  anglez for series '))
fig, ax = plt.subplots(figsize=(20, 3))
sns.lineplot(data=tmp1, x="step", y="anglez", linewidth = 0.5)
plt.show();
# Out:
# ###  anglez for series

# %%
display(Markdown('###  enmo for series '))
fig, ax = plt.subplots(figsize=(20, 3))
sns.lineplot(data=tmp1, x="step", y="enmo", linewidth = 0.5)
plt.show();
# Out:
# ###  enmo for series
